# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import plotly.express as px

# %%
jsn_path = Path().resolve() / "Logs" / "svc.jsonl"
data = pd.read_json(jsn_path , lines = True)

# %%
params = pd.json_normalize(data['params'])

# %%
df = pd.concat([data[["target"]], params], axis = 1)
df.target = df.target*-1

# %%
df1 = df.query("target < -0.87")

# %%
px.scatter_3d(df1, x = "C", y = "gamma", z = "target", color = "target")
# Out:
# <div>                            <div id="bf49b9c5-d027-41c4-b0f1-2641770bd6eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf49b9c5-d027-41c4-b0f1-2641770bd6eb")) {                    Plotly.newPlot(                        "bf49b9c5-d027-41c4-b0f1-2641770bd6eb",                        [{"hovertemplate":"C=%{x}\u003cbr\u003egamma=%{y}\u003cbr\u003etarget=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[-0.8729407641079561,-0.873116018226428,-0.872415001752541,-0.8710129688047661,-0.8745180511742021,-0.8759200841219761,-0.8717139852786541,-0.8729407641079561,-0.87434279705573,-0.8746933052926741,-0.8732912723449001,-0.871188222923238,-0.8759200841219761,-0.873641780581843,-0.872590255871013,-0.872239747
# ...

# %%
px.scatter(df1, x="gamma", y="target", hover_name=['C'], color="target")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/Proyecto-Modelado-Predictivo-Magic/Optimizacion_hiperparam/Optimization_analysis.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Borganic-space-orbit-g5gggqj66442ppp9/workspaces/Proyecto-Modelado-Predictivo-Magic/Optimizacion_hiperparam/Optimization_analysis.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> px.scatter(df1, x="gamma", y="target", hover_name=['C'], color="target")
#
# ...

# %%
df1.sort_values(by = "target", ascending = True).head(10)
# Out:
#        target           C     gamma
# 41  -0.875920   92.193361  0.106529
# 60  -0.875920  196.247357  0.087432
# 244 -0.875745  310.156134  0.073910
# 264 -0.875745   68.335565  0.142189
# 312 -0.875219  138.722324  0.093836
# 236 -0.875044  281.370248  0.073117
# 104 -0.874869  185.299176  0.035674
# 308 -0.874869   76.907173  0.106411
# 249 -0.874869  365.263325  0.068545
# 89  -0.874693   38.111771  0.084782
